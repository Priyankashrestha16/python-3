# %% [markdown]
# String Function
#
# lower()---all lowercase
# upper()---all uppercase
# capitalize()----first letter capital

# %%
text='domestic'

print(text.capitalize())
print(text.upper())
print(text.lower())
# Out:
# Domestic
# DOMESTIC
# domestic
