# %%
#first class
#variable =string value
first_name="Ram"

# %%
print(first_name)
# Out:
# Ram

# %%
# product details
product_id=1
product_category='Mobile Phone'
product_quantity=2
product_price= 25000
product_name="product"
total_price=product_quantity * product_price   # the output will give a integer value

# %%
print(product_price)
print(product_category)
print(product_id)
print(product_name)
print(total_price)
# Out:
# 25000
# Mobile Phone
# 1
# product
# 50000

# %%
print('Product ID:', product_id)
print('Product ID:' ,34)
print('Product Price', product_price)

#format string (f string)
print(f'Product Price:{product_price}')
print('Product Price', product_price)
#both results in same output
# Out:
# Product ID: 1
# Product ID: 34
# Product Price 25000
# Product Price:25000
# Product Price 25000

# %%
print(product_price)
print(f'product id {product_id} + productcategory {product_category}')

#type casting== changing variable type
# Out:
# 25000
# product id 1 + productcategory Mobile Phone

# %%
#heading 1

# %% [markdown]
# # Heading 1

# %%
## Heading 2

# %% [markdown]
# ## Heading 2

# %%
### Heading 3

# %%
#### Heading 4

# %% [markdown]
# #### Heading 4

# %% [markdown]
# ### Heading 3

# %% [markdown]
# # Input Function

# %%
# Input Function === to take value from users 

product_id= int(input('Enter product id'))
product_category= input('Enter product category:')
product_quantity= int(input('Enter product quantity:'))

# type casting == input  function takes value in string so for product quantity it needs to be in integer type. therefore we used type casting to get the value in integer

# %%
# now the updated value are printed

print('Product ID:',product_id)
# Out:
# Product ID: 3

# %%
# escape sequence, coditional satatement, if else statement 

## download anconda
# skip registration
# windows 
# windows64 bit graphical installer
