# %% [markdown]
# Loop
# ( for, while)
# for loop ----used when we know how many loops or run does the program have to make
#   -for loop
#   -nested loop
#
# while loop -----used when there is infinite loop/runs
#    -while loop

# %%
#for loop
#for loop has range() function ------range(start(default=0),stop,step(default=1))

#wap to print 10 natural number 
for i in range(1,11):
    print(i)
