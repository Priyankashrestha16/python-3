# %%
'''

1.BeautifulSoup
2. Selenium 

'''

# %%
# %pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.46.0-py3-none-any.whl (9.4 MB)
#      ---------------------------------------- 9.4/9.4 MB 2.4 MB/s eta 0:00:00
# Collecting certifi>=2026.2.25
#   Downloading certifi-2026.7.22-py3-none-any.whl (136 kB)
#      -------------------------------------- 137.0/137.0 kB 4.1 MB/s eta 0:00:00
# Collecting trio<1.0,>=0.31.0
#   Downloading trio-0.33.0-py3-none-any.whl (510 kB)
#      -------------------------------------- 510.3/510.3 kB 2.9 MB/s eta 0:00:00
# Collecting trio-websocket<1.0,>=0.12.2
#   Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Collecting websocket-client<2.0,>=1.8.0
#   Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
#      ---------------------------------------- 82.6/82.6 kB 2.3 MB/s eta 0:00:00
# Collecting urllib3[socks]<3.0,>=2.6.3
#   Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
#      -------------------------------------- 131.1/131.1 kB 2.6 MB/s eta 0:00:00
# Collecting typing_extensions<5.0,>=4.15.0
#   Downloading typing_extensions-4.16.0-py3-none-any.whl (45 kB)
#      ---------------------------------------- 45.6/45.6 kB 2.4 MB/s eta 0:00:00
# Collecting sortedcontainers
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: idna in c:\users\priyanka shrestha\appdata\local\programs\python\python310\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.10)
# Requirement already satisfied: exceptiongroup in c:\users\priyanka shrestha\appdata\local\programs\python\python310\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\priyanka shrestha\appdata\local\programs\python\python310\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.0.0)
# Collecting attrs>=23.2.0
#   Downloading attrs-26.1.0-py3-none-any.whl (67 kB)
#      ---------------------------------------- 67.5/67.5 kB 3.6 MB/s eta 0:00:00
# Collecting outcome
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Collecting sniffio>=1.3.0
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: pycparser in c:\users\priyanka shrestha\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (3.0)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\users\priyanka shrestha\appdata\local\programs\python\python310\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Installing collected packages: sortedcontainers, wsproto, websocket-client, urllib3, typing_extensions, sniffio, pysocks, certifi, attrs, outcome, trio, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.14.1
#     Uninstalling typing_extensions-4.14.1:
#       Successfully uninstalled typing_extensions-4.14.1
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.8.3
#     Uninstalling certifi-2025.8.3:
#       Successfully uninstalled certifi-2025.8.3
# Successfully installed attrs-26.1.0 certifi-2026.7.22 outcome-1.3.0.post0 pysocks-1.7.1 selenium-4.46.0 sniffio-1.3.1 sortedcontainers-2.4.0 trio-0.33.0 trio-websocket-0.12.2 typing_extensions-4.16.0 urllib3-2.7.0 websocket-client-1.9.0 wsproto-1.3.2
# [notice] A new release of pip available: 22.2.2 -> 26.2.1
# [notice] To update, run: C:\Users\PRIYANKA SHRESTHA\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip
# Collecting selenium
#   Downloading selenium-4.46.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting certifi>=2026.2.25 (from selenium)
#   Downloading certifi-2026.7.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Downloading trio-0.33.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\users\priyanka shrestha\appdata\roaming\python\python313\site-packages (from selenium) (4.15.0)
# Collecting urllib3<3.0,>=2.6.3 (from urllib3[socks]<3.0,>=2.6.3->selenium)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting websocket-client<2.0,>=1.8.0 (from selenium)
#   Downloading websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\priyanka shrestha\appdata\local\programs\python\python313\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (24.2.0)
# Collecting sortedcontainers (from trio<1.0,>=0.31.0->selenium)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in c:\users\priyanka shrestha\appdata\local\programs\python\python313\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.10)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio<1.0,>=0.31.0->selenium)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: cffi>=1.14 in c:\users\priyanka shrestha\appdata\local\programs\python\python313\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pysocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3.0,>=2.6.3->selenium)
#   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pycparser in c:\users\priyanka shrestha\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.22)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\users\priyanka shrestha\appdata\local\programs\python\python313\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.46.0-py3-none-any.whl (9.4 MB)
#    ---------------------------------------- 0.0/9.4 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.4 MB 1.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.0/9.4 MB 1.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/9.4 MB 1.8 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/9.4 MB 1.7 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.4 MB 1.8 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.4/9.4 MB 1.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.6/9.4 MB 1.7 MB/s eta 0:00:05
#    ------------- -------------------------- 3.1/9.4 MB 1.7 MB/s eta 0:00:04
#    -------------- ------------------------- 3.4/9.4 MB 1.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.9/9.4 MB 1.8 MB/s eta 0:00:04
#    -------------------- ------------------- 4.7/9.4 MB 1.9 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.5/9.4 MB 2.1 MB/s eta 0:00:02
#    -------------------------- ------------- 6.3/9.4 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.8/9.4 MB 2.2 MB/s eta 0:00:02
#    --------------------------------- ------ 7.9/9.4 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.4 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.4 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.4/9.4 MB 2.4 MB/s eta 0:00:00
# Downloading certifi-2026.7.22-py3-none-any.whl (136 kB)
# Downloading trio-0.33.0-py3-none-any.whl (510 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
# Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, wsproto, websocket-client, urllib3, sniffio, pysocks, outcome, certifi, trio, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.8.30
#     Uninstalling certifi-2024.8.30:
#       Successfully uninstalled certifi-2024.8.30
# Successfully installed certifi-2026.7.22 outcome-1.3.0.post0 pysocks-1.7.1 selenium-4.46.0 sniffio-1.3.1 sortedcontainers-2.4.0 trio-0.33.0 trio-websocket-0.12.2 urllib3-2.7.0 websocket-client-1.9.0 wsproto-1.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from selenium import webdriver  # wendriver used to access webbrowser
from selenium.webdriver.common.by import By #used to access website elements/ html tags

# %%
website='https://merolagani.com/LatestMarket.aspx'

# %% [markdown]
# access web browser

# %%
driver= webdriver.Chrome()

# %%
driver.get(website)

# %%
thead=driver.find_element(By.TAG_NAME,'tbody')

# %%
table_rows= driver.find_elements(By.TAG_NAME,'tr')

# %%
# for row in table_rows:
#     columns=row.find_elements(By.TAG_NAME,'td')
#     for col in columns:
#         print(col.text)

# %%
symbol_col=[]
ltp_col=[]
change_col=[]
open_col=[]
high_col=[]
low_col=[]
qty_col=[]
pclose_col=[]
dif_col=[]

# %%
for row in table_rows:
    columns=row.find_elements(By.TAG_NAME,'td')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 4
#       1 for row in table_rows:
#       2     columns=row.find_elements(By.TAG_NAME,'td')
#       3
# ----> 4     symbol_col.append(columns[0].text)
#       5     ltp_col.append(columns[1].text)
#       6     change_col.append(columns[2])
#       7     open_col.append(columns[3].text)
#
# IndexError: list index out of range
