# %% [markdown]
# Requirements

# %%
import random

# %%
all_accounts=[]

# %%
class DepositAmountError(Exception):
    pass

class WithdrawAmountError(Exception):
    pass

class AccountNumberError(Exception):
    pass

# %%
class Bank:
    def __init__(self,name, initial_balance,job,phone):
        self.name=name
        self.initial_balance=initial_balance
        self.job=job
        self.phone=phone
        self.account_number=self.name[1:3]+"".join(str(random.randint(0,9)) for i in range(16))+ 'NB'

    #Deposit Amount
    def deposit_amount(self,amount):
        if amount>=100:
            self.initial_balance+=amount
            print(f'Rs {amount} has been deposited to {self.account_number}')
        else:
            raise  DepositAmountError('Deposit amount must be more than Rs.100.')

    #Withdrawn Amount
    def withdrawamount(self,amount):
        if amount<self.initial_balance:
            if amount >=100:
                self.initial_balance -=amount
                print(f'Rs {amount} has been withdrawn from A/C no. {self.account_number}')
            else:
                print('Deposit amount must be more than Rs.100.')
        else:
            raise WithdrawAmountError('withdrawn amount must be less than initial balance.')

    #show user details
    def userdetails(self):
        print(f'Account Name: {self.name}')
        print(f'Account Number: {self.account_number}')
        print(f'Initial Balance:Rs{self.initial_balance}')
        print(f'Phone Number: {self.phone}')
        print(f'Job Position: {self.job}')

# %%
b= Bank('Nimesh',1300,'CEO','9283782233')
all_accounts.append(b)

# %%
for accounts in all_accounts:
    accounts.userdetails()
# Out:
# Account Name: Nimesh
# Account Number: im7229361083900111NB
# Initial Balance:Rs1300
# Phone Number: 9283782233
# Job Position: CEO

# %%
def findAccount(acc_number):
    for accounts in all_accounts:
        if accounts.account_number==acc_number:
            return accounts
    return None

# %%
while True:
    print('Welcome to Bank Application')
    print('1.Create Account')
    print('2.Deposit Account')
    print('3.WIthdraw Account')
    print('4.User Details')
    print('5.Exit')
    print('\n')

    choice=input('Enter your choice: ')
    if choice==1:
        yes_no=print('Do you want to create account? (yes/no)')
        if yes_no=='yes':
        
            print('Create Account')
            name=input("Enter your name: ")
            initial_balance=float('enter your balance: ')
            job=input('enter your job: ')
            phone=int(input('enter your phone number:'))
            try:
                if initial_balance>=100:
                    b=Bank(name,initial_balance,job,phone)
                    print(f'Account created for {name} with account number {b.account_number}')
                 
            except DepositAmountError as de:
               print(de)
        else:
            print('Continue with the transaction')


        print('\n')

    elif choice==2:
        yes_no=print('Do you want to deposit amount? (yes/no)')
        if yes_no=='yes':
            print('Deposit Account')
            account=input('enter your account number: ')
            find_acc= findAccount(account)
            try:
                if find_acc:
                    amount=input('enter your deposit amount: ')
                    find_acc.deposit_amount(amount)
            except DepositAmountError as we:
                print(we)

            print('\n')
    elif choice==3:
        yes_no=print('Do you want to withdraw amount? (yes/no)')
        if yes_no=='yes':
            print('Withdraw Account')
            account=input('enter your account number: ')
            find_acc= findAccount(account)
            try:
                if find_acc:
                    amount=input('enter withdraw amount: ')
                    find_acc.withdraw_amount(amount)
            except AccountNumberError as ace:
                print(ace)
        
            print('\n')
        else:
            print('Continue with the transaction.')
            
    elif choice==4:
        print('Your Details')
        print('\n')

    elif choice==5:
        print('Thank You for choosing us.')
        print('\n')
        break

    else:
        print('Exit')
# Out:
# Welcome to Bank Application
# 1.Create Account
# 2.Deposit Account
# 3.WIthdraw Account
# 4.User Details
# 5.Exit
#
#
# Exit
# Welcome to Bank Application
# 1.Create Account
# 2.Deposit Account
# 3.WIthdraw Account
# 4.User Details
# 5.Exit
#
#
# Exit
# Welcome to Bank Application
# 1.Create Account
# 2.Deposit Account
# 3.WIthdraw Account
# 4.User Details
# 5.Exit

# %%
# separate files and use of CLI and
